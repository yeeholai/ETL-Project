# %%
import pandas as pd
import numpy as np

# %%
mig_2014 = pd.read_excel("Resources/State_to_State_Migrations_Table_2014.xls")

# %%
# drop rows that are completely empty
mig_2014.dropna(how='all',inplace=True)

mig_2014
# Out:
#    Table with row headers in column A, L, W, AH, AS, BD, BO, BZ, CK, CV, and DG, and column headers in rows 6 through 8 and 45 through 47.  \
# 0     Table 1.  State-to-State Migration Flows1: 2014
# 1   Dataset: 2014 American Community Survey 1-Year...
# 2                Universe: Population 1 year and over
# 4                                   Current residence
# 5                                                 NaN
# ..                                                ...
# 80  3Movers within Puerto Rico are included in the...
# 81  MOE - Margin of error based on 90% confidence ...
# 82                               N/A - Not Applicable
# 83  For more information on state-to-state migrati...
# 84  Source: U.S. Census Bureau, 2014 American Comm...
#
#                     Unnamed: 1 Unnamed: 2             Unnamed: 3 Unnamed: 4  \
# 0                          NaN        NaN                    NaN        NaN
# 1                          NaN        NaN                    NaN        NaN
# ...

# %%
# keep the middle portion of the table. drop header and footer comments
mig_2014 = mig_2014.iloc[3:62,:].reset_index(drop=True)

# %%
# drop column headers that appear in the middle of the dataset
mig_2014.drop(mig_2014.index[31:34], inplace=True)

# %%
# fill in NAs in row[1] with values from row above, ie "population 1 year and over" etc.
mig_2014.iloc[:2,:9].ffill(inplace=True)

# %%
# drop columns that are repeating row headers, except the first occurrence, which will be used as row index
mig_2014 = mig_2014.drop(columns=mig_2014.columns[(mig_2014 == "Current residence").any()][1:])

# %%
# reset index with states name
mig_2014.set_index(mig_2014.iloc[:,0].name, inplace=True)

# %%
# drop every other column (keep Estimate columns only)
mig_2014 = mig_2014[[k for i, k in enumerate(mig_2014.columns,1) if i %2!=0]]

# %%
# reset index in preparation for next step- renaming column headers with row[1], removing the ugly "Table with row..."
mig_2014.reset_index(inplace=True)

# %%
# rename column headers with state names from row 1
mig_2014.rename(columns=mig_2014.iloc[1], inplace=True)

# %%
# Remove the first 3 rows in df, which are unnecessary column headers
mig_2014= mig_2014.iloc[3:,:]

# reset index with states name
mig_2014.set_index(mig_2014.iloc[:,0].name, inplace=True)

# rename "Total" column header
mig_2014.rename(columns={"Total":"Different state of residence 1 year ago"}, inplace=True)

mig_2014
# Out:
#                       Population 1 year and over Same house 1 year ago  \
# Current residence
# United States2                         315095393             268147625
# Alabama                                  4791931               4081522
# Alaska                                    725206                585916
# Arizona                                  6651964               5431241
# Arkansas                                 2931123               2464189
# California                              38340324              32849251
# Colorado                                 5293943               4263998
# Connecticut                              3558915               3111779
# Delaware                                  924770                810905
# District of Columbia                      648586                513634
# Florida                                 19683763              16504838
# Georgia                                  9970167               8406436
# ...

# %%
mig_2014.to_dict()
# Out:
# <ipython-input-13-f515e327342c>:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   mig_2014.to_dict()
# {'Population 1 year and over': {'United States2': 315095393,
#   'Alabama': 4791931,
#   'Alaska': 725206,
#   'Arizona': 6651964,
#   'Arkansas': 2931123,
#   'California': 38340324,
#   'Colorado': 5293943,
#   'Connecticut': 3558915,
#   'Delaware': 924770,
#   'District of Columbia ': 648586,
#   'Florida': 19683763,
#   'Georgia': 9970167,
#   'Hawaii': 1401004,
#   'Idaho': 1613068,
#   'Illinois': 12730206,
#   'Indiana': 6516181,
#   'Iowa': 3067872,
#   'Kansas': 2866584,
#   'Kentucky': 4357819,
#   'Louisiana': 4593505,
#   'Maine': 1317638,
#   'Maryland': 5911235,
#   'Massachusetts': 6674907,
#   'Michigan': 9795659,
#   'Minnesota': 5385219,
#   'Mississippi': 2957658,
#   'Missouri': 5992195,
#   'Montana': 1012169,
#   'Nebraska': 1855356,
#   'Nevada': 2806170,
#   'New Hampshire': 1314735,
#   'New Jersey': 8840346,
# ...
