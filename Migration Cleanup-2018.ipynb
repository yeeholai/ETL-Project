# %%
import pandas as pd
import numpy as np

# %%
mig_2018 = pd.read_excel("Resources/State_to_State_Migrations_Table_2018.xls")

# %%
# drop rows that are completely empty
mig_2018.dropna(how='all',inplace=True)

# %%
# keep the middle portion of the table. drop header and footer comments
mig_2018 = mig_2018.iloc[3:62,:].reset_index(drop=True)

# %%
# drop column headers that appear in the middle of the dataset
mig_2018.drop(mig_2018.index[31:34], inplace=True)

# %%
# fill in NAs in row[1] with values from row above, ie "population 1 year and over" etc.
mig_2018.iloc[:2,:9].ffill(inplace=True)

# %%
# drop columns that are repeating row headers, except the first occurrence, which will be used as row index
mig_2018 = mig_2018.drop(columns=mig_2018.columns[(mig_2018 == "Current residence in").any()][1:])

# %%
# reset index with states name
mig_2018.set_index(mig_2018.iloc[:,0].name, inplace=True)

# %%
# drop every other column (keep Estimate columns only)
mig_2018 = mig_2018[[k for i, k in enumerate(mig_2018.columns,1) if i %2!=0]]

# %%
# reset index in preparation for next step- renaming column headers with row[1], removing the ugly "Table with row..."
mig_2018.reset_index(inplace=True)

# %%
# rename column headers with state names from row 1
mig_2018.rename(columns=mig_2018.iloc[1], inplace=True)

# %%
# Remove the first 3 rows in df, which are unnecessary column headers
mig_2018= mig_2018.iloc[3:,:]

# reset index with states name
mig_2018.set_index(mig_2018.iloc[:,0].name, inplace=True)

# rename "Total" column header
mig_2018.rename(columns={"Total":"Different state of residence 1 year ago"}, inplace=True)

mig_2018
# Out:
#                       Population 1 year and over Same house 1 year ago  \
# Current residence in
# United States2                         323531965             278079469
# Alabama                                  4832358               4173026
# Alaska                                    727164                608707
# Arizona                                  7090137               5887700
# Arkansas                                 2975961               2539294
# California                              39114889              34232867
# Colorado                                 5633029               4626834
# Connecticut                              3538203               3102312
# Delaware                                  958770                853523
# District of Columbia                      693798                568201
# Florida                                 21092877              17863603
# Georgia                                 10410462               8909803
# ...

# %%
mig_2018.to_dict()
# Out:
# <ipython-input-13-aca2895cb25c>:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   mig_2018.to_dict()
# {'Population 1 year and over': {'United States2': 323531965,
#   'Alabama': 4832358,
#   'Alaska': 727164,
#   'Arizona': 7090137,
#   'Arkansas': 2975961,
#   'California': 39114889,
#   'Colorado': 5633029,
#   'Connecticut': 3538203,
#   'Delaware': 958770,
#   'District of Columbia ': 693798,
#   'Florida': 21092877,
#   'Georgia': 10410462,
#   'Hawaii': 1403653,
#   'Idaho': 1734756,
#   'Illinois': 12599244,
#   'Indiana': 6612948,
#   'Iowa': 3119306,
#   'Kansas': 2874208,
#   'Kentucky': 4414714,
#   'Louisiana': 4603081,
#   'Maine': 1324095,
#   'Maryland': 5974521,
#   'Massachusetts': 6834364,
#   'Michigan': 9891083,
#   'Minnesota': 5543490,
#   'Mississippi': 2955717,
#   'Missouri': 6053109,
#   'Montana': 1051757,
#   'Nebraska': 1905843,
#   'Nevada': 3003761,
#   'New Hampshire': 1344750,
#   'New Jersey': 8815804,
# ...
