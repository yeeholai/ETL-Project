# %%
import pandas as pd
import numpy as np

# %%
mig_2019 = pd.read_excel("Resources/State_to_State_Migrations_Table_2019.xls")

# %%
# drop rows that are completely empty
mig_2019.dropna(how='all',inplace=True)

# %%
# keep the middle portion of the table. drop header and footer comments
mig_2019 = mig_2019.iloc[3:62,:].reset_index(drop=True)

# %%
# drop column headers that appear in the middle of the dataset
mig_2019.drop(mig_2019.index[31:34], inplace=True)

# %%
# fill in NAs in row[1] with values from row above, ie "population 1 year and over" etc.
mig_2019.iloc[:2,:9].ffill(inplace=True)

# %%
# drop columns that are repeating row headers, except the first occurrence, which will be used as row index
mig_2019 = mig_2019.drop(columns=mig_2019.columns[(mig_2019 == "Current residence in").any()][1:])

# %%
# reset index with states name
mig_2019.set_index(mig_2019.iloc[:,0].name, inplace=True)

# %%
# drop every other column (keep Estimate columns only)
mig_2019 = mig_2019[[k for i, k in enumerate(mig_2019.columns,1) if i %2!=0]]

# %%
# reset index in preparation for next step- renaming column headers with row[1], removing the ugly "Table with row..."
mig_2019.reset_index(inplace=True)

# %%
# rename column headers with state names from row 1
mig_2019.rename(columns=mig_2019.iloc[1], inplace=True)

# %%
# Remove the first 3 rows in df, which are unnecessary column headers
mig_2019= mig_2019.iloc[3:,:]

# reset index with states name
mig_2019.set_index(mig_2019.iloc[:,0].name, inplace=True)

# rename "Total" column header
mig_2019.rename(columns={"Total":"Different state of residence 1 year ago"}, inplace=True)

mig_2019
# Out:
#                       Population 1 year and over Same house 1 year ago  \
# Current residence in
# United States2                         324665523             280343146
# Alabama                                  4849509               4197698
# Alaska                                    722063                609362
# Arizona                                  7200620               6038776
# Arkansas                                 2989054               2559444
# California                              39084048              34394220
# Colorado                                 5701658               4695821
# Connecticut                              3531986               3106754
# Delaware                                  964817                843383
# District of Columbia                      697556                563798
# Florida                                 21269409              18083185
# Georgia                                 10499808               9034705
# ...

# %%
mig_2019.to_dict()
# Out:
# <ipython-input-13-9347c228c680>:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   mig_2019.to_dict()
# {'Population 1 year and over': {'United States2': 324665523,
#   'Alabama': 4849509,
#   'Alaska': 722063,
#   'Arizona': 7200620,
#   'Arkansas': 2989054,
#   'California': 39084048,
#   'Colorado': 5701658,
#   'Connecticut': 3531986,
#   'Delaware': 964817,
#   'District of Columbia ': 697556,
#   'Florida': 21269409,
#   'Georgia': 10499808,
#   'Hawaii': 1396819,
#   'Idaho': 1764327,
#   'Illinois': 12536539,
#   'Indiana': 6656971,
#   'Iowa': 3121385,
#   'Kansas': 2879518,
#   'Kentucky': 4421512,
#   'Louisiana': 4595111,
#   'Maine': 1331656,
#   'Maryland': 5979602,
#   'Massachusetts': 6828110,
#   'Michigan': 9880758,
#   'Minnesota': 5575235,
#   'Mississippi': 2943737,
#   'Missouri': 6069697,
#   'Montana': 1056994,
#   'Nebraska': 1910711,
#   'Nevada': 3048602,
#   'New Hampshire': 1350155,
#   'New Jersey': 8791672,
# ...
