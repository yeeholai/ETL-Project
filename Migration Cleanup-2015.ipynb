# %%
import pandas as pd
import numpy as np

# %%
mig_2015 = pd.read_excel("Resources/State_to_State_Migrations_Table_2015.xls")

# %%
# drop rows that are completely empty
mig_2015.dropna(how='all',inplace=True)

# %%
# keep the middle portion of the table. drop header and footer comments
mig_2015 = mig_2015.iloc[3:62,:].reset_index(drop=True)

# %%
# drop column headers that appear in the middle of the dataset
mig_2015.drop(mig_2015.index[31:34], inplace=True)

# %%
# fill in NAs in row[1] with values from row above, ie "population 1 year and over" etc.
mig_2015.iloc[:2,:9].ffill(inplace=True)

# %%
# drop columns that are repeating row headers, except the first occurrence, which will be used as row index
mig_2015 = mig_2015.drop(columns=mig_2015.columns[(mig_2015 == "Current residence in --").any()][1:])

# %%
# reset index with states name
mig_2015.set_index(mig_2015.iloc[:,0].name, inplace=True)

# %%
# drop every other column (keep Estimate columns only)
mig_2015 = mig_2015[[k for i, k in enumerate(mig_2015.columns,1) if i %2!=0]]

# %%
# reset index in preparation for next step- renaming column headers with row[1], removing the ugly "Table with row..."
mig_2015.reset_index(inplace=True)

# %%
# rename column headers with state names from row 1
mig_2015.rename(columns=mig_2015.iloc[1], inplace=True)

# %%
# Remove the first 3 rows in df, which are unnecessary column headers
mig_2015= mig_2015.iloc[3:,:]

# reset index with states name
mig_2015.set_index(mig_2015.iloc[:,0].name, inplace=True)

# rename "Total" column header
mig_2015.rename(columns={"Total":"Different state of residence 1 year ago"}, inplace=True)

mig_2015
# Out:
#                         Population 1 year and over Same house 1 year ago  \
# Current residence in --
# United States2                           317635720             270873397
# Alabama                                    4801599               4113945
# Alaska                                      727862                582909
# Arizona                                    6747595               5536087
# Arkansas                                   2938341               2440359
# California                                38675135              33446324
# Colorado                                   5393067               4404058
# Connecticut                                3554844               3109580
# Delaware                                    935813                800701
# District of Columbia                        663006                525024
# Florida                                   20068392              16832374
# ...

# %%
mig_2015.to_dict()
# Out:
# <ipython-input-13-9818beb27c30>:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   mig_2015.to_dict()
# {'Population 1 year and over': {'United States2': 317635720,
#   'Alabama': 4801599,
#   'Alaska': 727862,
#   'Arizona': 6747595,
#   'Arkansas': 2938341,
#   'California': 38675135,
#   'Colorado': 5393067,
#   'Connecticut': 3554844,
#   'Delaware': 935813,
#   'District of Columbia ': 663006,
#   'Florida': 20068392,
#   'Georgia': 10088525,
#   'Hawaii': 1414355,
#   'Idaho': 1635366,
#   'Illinois': 12706393,
#   'Indiana': 6540691,
#   'Iowa': 3081446,
#   'Kansas': 2875640,
#   'Kentucky': 4373403,
#   'Louisiana': 4612024,
#   'Maine': 1317444,
#   'Maryland': 5934005,
#   'Massachusetts': 6725678,
#   'Michigan': 9811416,
#   'Minnesota': 5419822,
#   'Mississippi': 2959289,
#   'Missouri': 6015580,
#   'Montana': 1019646,
#   'Nebraska': 1869217,
#   'Nevada': 2859489,
#   'New Hampshire': 1318121,
#   'New Jersey': 8854363,
# ...
